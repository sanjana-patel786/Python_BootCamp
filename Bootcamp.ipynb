# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjana-patel786/Python_BootCamp/blob/main/Bootcamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world ")
# Out:
# hello world

# %%
print ("This is python bootcamp")
# Out:
# This is python bootcamp

# %%
#Day 1

# %%
#challange 1

name = input("enter your name:")
color = input("enter your fav color:")
print("Hello", name,"!")
print("Your favourite color is", color,".")
# Out:
# enter your name:sanjana
# enter your fav color:teal
# Hello sanjana !
# Your favourite color is teal .

# %%
#challenge2
age = int(input("enter your age:"))
bage = age - 10
fage = age + 10
print("your age 10 years ago:",bage)
print("your age after 10 years:",fage)
# Out:
# enter your age:22
# your age 10 years ago: 12
# your age after 10 years: 32

# %%
#challenge 3
num1 = int(input("enter first number:"))
num2 = int(input("enter second number:"))
Addition = num1 + num2
Subtraction = num1 - num2
Multiplication = num1 * num2
Division = num1 / num2
print("Addition:",Addition)
print("Subtrcation:",Subtraction)
print("Multiplication:",Multiplication)
print("Division:",Division)
# Out:
# enter first number:30
# enter second number:20
# Addition: 50
# Subtrcation: 10
# Multiplication: 600
# Division: 1.5

# %%
#Challenge 4
len = int(input("enter lenghth:"))
bre = int(input("enter width:"))
area = len*bre
perimeter = (len+bre)/2
print("Area:",area)
print("Perimeter:",perimeter)
# Out:
# enter lenghth:5
# enter width:4
# Area: 20
# Perimeter: 4.5

# %%
#challange 5
name = input("enter name:")
age = int(input("enter age:"))
city = input("enter city:")
job = input("enter job:")
print("Hi! My name is",name+".")
print("I am",age ,"old.")
print("I live in:",city+".")
print("My dream is to become a",job+".")
# Out:
# enter name:Sanjnaa
# enter age:22
# enter city:Mumbai
# enter job:User
# Hi! My name is Sanjnaa.
# I am 22 old.
# I live in: Mumbai.
# My dream is to become a User.

# %%
# homework pizza bill calculator

name=input("enter name:")
num=int(input("enter number of pizzas:"))
price=int(input("enter price of one pizza:"))
bill = num*price
print("Customer:",name)
print("Number of pizzas:",num)
print("Price of one pizza:",price)
print("Total bill:",bill)
# Out:
# enter name:jen
# enter number of pizzas:3
# enter price of one pizza:250
# Customer: jen
# Number of pizzas: 3
# Price of one pizza: 250
# Total bill: 750

# %%
#boss problem
name=input("enter name:")
bear = int(input("enter birth year"))
cear = int(input("enter year"))
age = cear-bear
print("Hello!",name)
print("You are",age,"years old.")
# Out:
# enter name:Jen
# enter birth year2007
# enter year2026
# Hello! Jen
# You are 19 years old.

# %%
# bonus challenge
name = input("enter name:")
num = int(input("enter number:"))
price = int(input("enter price per ticket:"))
amt = num*price
print("Customer:",name)
print("Tickets:",num)
print("Price per ticket:",price)
print("Total amount:",amt)
# Out:
# enter name:jen
# enter number:4
# enter price per ticket:180
# Customer: jen
# Tickets: 4
# Price per ticket: 180
# Total amount: 720

# %%
# Day 2

# %%
#ques 1
num = int(input("enter number:"))

if num>0:
  print("Positive")
elif num<0:
  print("Negative")
else:
  print("Zero")
# Out:
# enter number:0
# Zero

# %%
num1 = int(input("enter number:"))
num2 = int(input("enter number:"))
if num1>num2:
  print(num1,"is greater than",num2)
else:
  print(num2,"is greater than",num1)
# Out:
# enter number:25
# enter number:68
# 68 is greater than 25

# %%
#ques 3
mark = int(input("enter marks:"))
if mark>=90:
  print("Grade A")
elif mark>=75:
  print("Grade B")
elif mark>=60:
  print("Grade C")
elif mark>=40:
  print("Grade D")
else:
  print("Fail")
# Out:
# enter marks:35
# Fail

# %%
ear = int(input("enter year:"))
if (ear%4==0):
  print(ear,"is a leap year.")
else:
  print(ear,"is not a leap year")
# Out:
# enter year:2026
# 2026 is not a leap year

# %%
#bonus calcualtor

fnum=int(input("enter first number:"))
snum=int(input("enter second number:"))
op=input("enter operation:")
if op=="+":
  print(fnum+snum)
elif op=="-":
  print(fnum-snum)
elif op=="*":
  print(fnum*snum)
elif op=="/":
  print(fnum/snum)
else:
  print("invalid operation")
# Out:
# enter first number:5
# enter second number:4
# enter operation:*
# 20

# %%
#mini challenge
pw = input("enter password:")
if pw == "python123":
  print("Access Granted")
else:
  print("Access Denied")
# Out:
# enter password:123
# Access Denied

# %%
#voting elgibilty cheker
age = int(input("enter age:"))
if age >= 18:
  print("You are eligible to vote")
else:
  print("You are not eligible to vote")
# Out:
# enter age:89
# You are eligible to vote

# %%
#ATM Pin checker
pin = int(input("enter pin:"))
if pin == 1234:
  print("Access Granted")
else:
  print("Access Denied")
# Out:
# enter pin:5413
# Access Denied

# %%
#task 2
num = int(input("enter number:"))
if num%5==0:
  print(num,"Divisible by 5")
else:
  print(num,"Not divisible by 5")
# Out:
# enter number:25
# 25 Divisible by 5

# %%
#task 3
password=input('enter password:')
if len(password)>=8:
  print("Strong Password")
else:
  print("Weak Password")
# Out:
# enter password:sanju
# Weak Password

# %%
#task 4
secret = 8
num = int(input("enter number:"))
if num == secret:
  print("Correct Guess!")
else:
  print("Try Again!")
# Out:
# enter number:3
# Try Again!

# %%
# task 5
age = int(input("enter age"))
if age<5:
  print("Free")
elif age<=17:
  print("₹100")
elif age<=59:
  print("₹200")
else:
  print("₹150")
# Out:
# enter age65
# ₹150

# %%
# Day 3

# %%
#challange 1
user = "admin"
password = "python123"
upp = input("enter username:")
uppw = input("enter password:")
if user == upp and password == uppw:
  print("Login Successful")
else:
  print("Invalid Credentails")
# Out:
# enter username:user
# enter password:1234
# Invalid Credentails

# %%
# challenge 2
age = int(input("enter age:"))
ctz = input("do you have citizenship:")
if age>=18 and ctz == "yes":
  print("Eligible to vote")
else:
  print("Not Eligible to vote")
# Out:
# enter age:17
# do you have citizenship:yes
# Not Eligible to vote

# %%
num = int(input("enter a number:"))
if num % 2 == 0 or num % 5 == 0:
  print("Accepted")
else:
  print("Rejected")
# Out:
# enter a number:25
# Accepted

# %%
ticket = input("do you have a ticket:")
if ticket != "yes":
  print("Entry Denied")
else:
  print("Welcome")
# Out:
# do you have a ticket:no
# Entry Denied

# %%
year = int(input("enter year:"))
if year % 400 ==0 or(year %4 ==0 and year%100 !=0):
  print("Leap Year")
else:
  print("Not a Leap Year")
# Out:
# enter year:2026
# Not a Leap Year

# %%
# Task 1
s1 = int(input("enter side 1:"))
s2 = int(input("enter side 2:"))
s3 = int(input("enter side 3:"))
if s1 == s2 == s3:
  print("Equilateral Triangle")
elif s1 == s2 or s1 == s3 or s2 == s3:
  print("Isosceles Triangle")
else:
  print("Scalene Triangle")
# Out:
# enter side 1:2
# enter side 2:3
# enter side 3:4
# Scalene Triangle

# %%
balance = 70000
withdrawl = int(input("Enter the Withdrawl Amount:"))
if withdrawl > 0 and withdrawl<=70000:
  print("Transaction Sucessful")
elif withdrawl>70000:
  print("Insufficent balance")
else:
  print("Invalid Transaction")
# Out:
# Enter the Withdrawl Amount:0
# Invalid Transaction

# %%
age = int(input("enter age:"))
salary= int(input("enter salary:"))
credit = int(input("enter credit score:"))
if age>=21 and salary>=25000 and credit>=700:
  print("Loan Finalised")
else:
  print("Loan rejected")

# %%
balance = 10000
print("Current Balance:",balance)
deposit = int(input("enter deposit:"))
new = balance + deposit
print("New Balance:",new)
withdrawl = int(input("enter withdrawl:"))
new2 = new - withdrawl
if new2>=0:
  print("given money:", new2)
  print("Thank you")
else:
  print("Invalid option")
# Out:
# Current Balance: 10000
# enter deposit:2000
# New Balance: 12000
# enter withdrawl:2000
# given money: 10000
# Thank you
